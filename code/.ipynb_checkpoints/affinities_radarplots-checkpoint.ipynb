# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
base_path = os.path.dirname(os.getcwd())
affinities_file = f'{base_path}/affinities/affinities_table.csv'
affinities = pd.read_csv(affinities_file)

# %%
affinities
# Out:
#    Receptors  Olanzapine  Clozapine  Norclozapine  Risperidone  Amisulpride  \
# 0     5-HT1A    2063.000    140.000        13.900      394.268      6773.00
# 1     5-HT1B     660.000    523.000       406.800       36.805      1744.00
# 2     5-HT1C      11.000        NaN           NaN          NaN          NaN
# 3     5-HT2A       3.300      7.800        10.900        0.355      4525.00
# 4     5-HT2B      11.800      7.360         2.800       35.392        43.50
# 5     5-HT2C         NaN     17.000           NaN       25.000     10000.00
# 6      5-HT6         NaN     10.471        11.600     1790.077      2755.00
# 7         D1      52.240    196.000        14.300      523.000     10000.00
# 8         D2      20.208    130.000       100.000        2.200         2.15
# 9         D3      44.668    242.000       153.000        6.700         9.70
# 10        D4      29.500     33.113        70.000        8.500      1980.00
# 11        D5      82.000    250.000       283.600      289.500     10000.00
# 12        H1       2.377      1.810         3.933       18.810     10000.00
# 13        M1       4.700      2.450        67.600     6606.934     10000.00
# 14        M2      87.500     65.588       414.500     8082.975     10000.00
# 15        M3      78.000     25.000        95.700    10000.000     10000.00
# 16        M4      32.000     19.000       169.900    10000.000     10000.00
# 17        M5       9.000     18.600        35.400    10000.000     10000.00
# 18    alpha1      54.954      7.900           NaN        2.050          NaN
# 19   alpha1A     112.000      1.600       104.800        5.000     10000.00
# 20   alpha1B     263.000      7.000        85.200        9.000     10000.00
# 21   alpha1D         NaN        NaN           NaN          NaN     10000.00
# 22    alpha2     280.000     96.556           NaN        6.550          NaN
# 23   alpha2A     314.050    110.716       304.800       23.000       607.50
# 24   alpha2B      82.000     26.500        95.100      107.600       465.00
# 25   alpha2C      55.500     34.000       117.700        2.250      1266.00
#
#     Flupentixol
# 0      8028.000
# 1           NaN
# 2           NaN
# 3        87.500
# 4           NaN
# 5           NaN
# 6           NaN
# 7         3.500
# 8         0.695
# 9         1.100
# 10       66.300
# 11        8.000
# 12        0.860
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          NaN
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# 24          NaN
# 25          NaN

# %%
def radar_plot(df, dname):
    ax = plt.subplot(1,1,1, polar=True)
    angles = [n / float(N) * 2 * np.pi for n in range(N)]
    ax.set_theta_offset(np.pi / 2)
    ax.set_theta_direction(-1)
    
    plt.xticks(angles, df['Receptors'], color='black', size=8)
    ax.tick_params(axis='x', rotation=5.5)
    
    ax.set_rlabel_position(0)
    plt.ylim(0,0.5)
    plt.yticks(np.arange(0,0.6,0.1),  size=0)
    affinity = np.nan_to_num(1/df[dname])
    
    ax.plot(angles, affinity, color = 'red', linewidth=1, linestyle='solid');
    ax.fill(angles, affinity, color = 'red', alpha = 0.5)

    plt.title(dname, size=16)
    plt.savefig(f'{base_path}/figs/{dname}_affinity_radarplot.jpg', dpi=300, transparent=True )
    plt.show()
    plt.close('all')

# %%
antipsychotics = ['Olanzapine', 'Clozapine', 'Norclozapine', 'Risperidone', 'Amisulpride', 'Flupentixol']
for antipsychotic in antipsychotics: 
    radar_plot(affinities, antipsychotic)
