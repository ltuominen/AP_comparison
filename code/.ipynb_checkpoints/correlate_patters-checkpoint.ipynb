# %%
# correlate effects

# %%
import os
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import pearsonr
from itertools import combinations 
from neuromaps.images import annot_to_gifti
from neuromaps.nulls import hungarian

# %%
base = os.path.dirname(os.getcwd())

flu = pd.read_csv(base + '/data/Flupentixol/Flupentixol_parcelwise.csv')
ami = pd.read_csv(base + '/data/Amisulpride/Amisulpride_parcelwise.csv')
ris = pd.read_csv(base + '/data/Risperidone/Risperidone_parcelwise.csv')
clo = pd.read_csv(base + '/data/Clozapine/Clozapine_parcelwise.csv')
ola = pd.read_csv(base + '/data/Olanzapine/Olanzapine_parcelwise.csv')

enigma_data = pd.read_csv(base + '/data/ENIGMA/ENIGMA_S32_partial_correlation_between_cortical_thickness_and_chlorpromazine_equivalents.csv')
enigma_data = enigma_data[:-2]

# %%
df = pd.DataFrame({'parcel':ola['parcel'], 'Enigma':enigma_data['partial_r'], 
                    'Clozapine':clz['hedges_g'],'Olanzapine':ola['hedges_g'], 
                   'Flupentixol':flu['hedges_g'], 'Amisulpride':ami['hedges_g'],
                  'Risperidone': ris['hedges_g']})

df['Olanzapine'] = df['Olanzapine']*7 # make the effectsize weekly (not sure how to deal with different times yet)

# %%
corr= np.round(df.loc[:,'Enigma':'Risperidone'].corr(),2)
mask = np.triu(np.ones_like(corr, dtype=bool))
f, ax = plt.subplots(figsize=(5,5))
h= sns.heatmap(corr, annot=True, mask=mask, square=True, vmax=0.64, vmin=-0.2, 
               cbar_kws={"shrink": .8,
                         "ticks": [-0.2, 0, 0.2, 0.4, 0.6],        # locations
                         "format": "%.1f"})
cbar = h.collections[0].colorbar     
cbar.ax.set_position([0.75, 0.25, 0.1, 0.4])
cbar.set_label("Pearson r", rotation=270, labelpad=15, fontsize=12)
ax.set_yticks([1.5, 2.5, 3.5, 4.5, 5.5]);
ax.set_xticks([0.5,1.5, 2.5, 3.5, 4.5]);

fname = f'{base}/figs/all_heatmap.jpg'
plt.savefig(fname, dpi=300, bbox_inches='tight')

# %%
# statistics with spins 


# get annot

dk_fsaverage_164k=(
    f'{base}/annot/atlas-desikankilliany_space-fsaverage_den-164k_hemi-L.aparc-1.annot',
    f'{base}/annot/atlas-desikankilliany_space-fsaverage_den-164k_hemi-R.aparc-1.annot'
)

dk_fsaverage_164k = annot_to_gifti(dk_fsaverage_164k)  # this does relabel_gift and also converts the annot file to gifti


# get spins 
spins = pd.read_csv(f'{base}/annot/spins_hungarian_aparc+aseg_ctx.csv', header=None)
nspins = spins.values.shape[1]

drugs = df.columns[1:].tolist()
pairs = list(combinations(drugs, 2))

for p in pairs:

    rho, _ = pearsonr(df[p[0]], df[p[1]])
    # get 10k rotations 
    rotated = hungarian(data=df[p[0]], n_perm=10000, spins=spins, parcellation=dk_fsaverage_164k) 
    
    # get null
    n = np.zeros((nspins, ))
    for i in range(nspins):
        n[i] = pearsonr(df[p[1]], rotated[:,i])[0]    
    
    # get p-value
    pspin = (1 + sum(abs(n) > abs(rho ))) / (nspins + 1)
    
    print(p, rho, pspin)
# Out:
# ('Enigma', 'Clozapine') 0.6284982985981814 0.00029997000299970003
# ('Enigma', 'Olanzapine') 0.4233185139562289 0.0014998500149985001
# ('Enigma', 'Flupentixol') 0.36587471832810686 0.006099390060993901
# ('Enigma', 'Amisulpride') 0.0463030877606802 0.7108289171082892
# ('Enigma', 'Risperidone') 0.039037986319045516 0.774022597740226
# ('Clozapine', 'Olanzapine') 0.3489771415352696 0.007399260073992601
# ('Clozapine', 'Flupentixol') 0.13570844844041238 0.31096890310968905
# ('Clozapine', 'Amisulpride') -0.15557527503706742 0.21007899210078992
# ('Clozapine', 'Risperidone') 0.012181266106359513 0.9227077292270773
# ('Olanzapine', 'Flupentixol') 0.07771814251830796 0.5327467253274673
# ('Olanzapine', 'Amisulpride') -0.14548571434719326 0.257974202579742
# ('Olanzapine', 'Risperidone') -0.17181632763598878 0.1673832616738326
# ('Flupentixol', 'Amisulpride') 0.1330489587299967 0.28447155284471554
# ('Flupentixol', 'Risperidone') 0.15572183466322567 0.20257974202579743
# ...

# %%
drugs = df.columns[1:].tolist()
pairs = list(combinations(drugs, 2))

for p in pairs:
    fig, ax = plt.subplots(figsize=(4,4))
    sns.despine()
    sns.regplot(df, x=p[0], y=p[1])
    ax.set_xlabel(p[0], size=14)
    ax.set_ylabel(p[1], size=14)
    r,_ = pearsonr(df[p[0]],df[p[1]])
    fname = f'{base}/figs/{p[0]}_{p[1]}_scatter.jpg'
    plt.savefig(fname, dpi=300, bbox_inches='tight')
