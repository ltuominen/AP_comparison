# %%
# plot risperidone

# %%
from surfplot import Plot
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import os
from utils import get_annot_labels
from utils import rois2maps
from neuromaps.datasets import fetch_fsaverage

# %%
base_path = os.path.dirname(os.getcwd())

dat = pd.read_csv(base_path + '/data/Risperidone/Risperidone_parcelwise.csv')

# make maps to plt
lh_dat = dat.loc[dat['parcel'].str.contains('lh_'),:]
lh_dat.loc[:,'hedges_g'] = lh_dat['hedges_g'] + 0.001 # weird 
rh_dat = dat.loc[dat['parcel'].str.contains('rh_'),:]

# %%
rh_dat
# Out:
#                          parcel  estimate   t-value   p-value     sigma  \
# 34                  rh_bankssts  0.019118  0.679168  0.501768  0.116060
# 35   rh_caudalanteriorcingulate  0.034706  1.688481  0.100749  0.084748
# 36       rh_caudalmiddlefrontal  0.043441  1.665915  0.105197  0.107516
# 37                    rh_cuneus  0.003235  0.249629  0.804421  0.053437
# 38                rh_entorhinal  0.086735  1.935936  0.061480  0.184727
# 39                  rh_fusiform  0.042912  1.320050  0.195902  0.134033
# 40          rh_inferiorparietal  0.045441  2.020914  0.051463  0.092710
# 41          rh_inferiortemporal  0.048529  1.542182  0.132565  0.129746
# 42          rh_isthmuscingulate  0.018971  1.251357  0.219603  0.062506
# 43          rh_lateraloccipital  0.026676  1.691693  0.100128  0.065018
# 44      rh_lateralorbitofrontal  0.030147  1.014004  0.317958  0.122583
# 45                   rh_lingual  0.010529  0.757580  0.454078  0.057306
# 46       rh_medialorbitofrontal  0.013118  0.482051  0.632952  0.112199
# 47            rh_middletemporal  0.049118  2.194088  0.035377  0.092301
# 48           rh_parahippocampal  0.040353  1.552780  0.130015  0.107149
# 49               rh_paracentral  0.049176  1.772102  0.085611  0.114418
# 50           rh_parsopercularis  0.032176  1.112212  0.274084  0.119282
# 51             rh_parsorbitalis  0.064353  1.793524  0.082058  0.147940
# 52          rh_parstriangularis  0.021353  0.745164  0.461447  0.118149
# 53             rh_pericalcarine  0.006941  0.355138  0.724746  0.080586
# 54               rh_postcentral  0.023794  1.247390  0.221035  0.078649
# 55        rh_posteriorcingulate  0.016294  0.873216  0.388855  0.076937
# 56                rh_precentral  0.038735  1.299284  0.202851  0.122921
# 57                 rh_precuneus  0.038353  1.926827  0.062649  0.082069
# 58  rh_rostralanteriorcingulate  0.067500  1.853126  0.072824  0.150184
# 59      rh_rostralmiddlefrontal  0.026912  1.141201  0.262000  0.097231
# 60           rh_superiorfrontal  0.028794  1.271714  0.212365  0.093355
# 61          rh_superiorparietal  0.038765  1.836171  0.075356  0.087046
# 62          rh_superiortemporal  0.053324  2.327626  0.026211  0.094456
# 63             rh_supramarginal  0.035118  1.339817  0.189459  0.108070
# 64               rh_frontalpole  0.043706  1.017022  0.316542  0.177188
# 65              rh_temporalpole  0.070735  1.518002  0.138537  0.192127
# 66        rh_transversetemporal  0.067029  1.949206  0.059813  0.141786
# 67                    rh_insula  0.021265  1.166970  0.251586  0.075132
#
#            df   cohen_d  hedges_g
# 34  33.000001  0.164722  0.160950
# 35  33.000001  0.409517  0.400139
# 36  33.000001  0.404044  0.394791
# 37  33.000001  0.060544  0.059158
# 38  33.000000  0.469534  0.458781
# 39  33.000000  0.320159  0.312827
# 40  33.000000  0.490144  0.478919
# 41  33.000000  0.374034  0.365469
# 42  33.000000  0.303499  0.296548
# 43  33.000001  0.410296  0.400900
# 44  33.000000  0.245932  0.240300
# 45  33.000001  0.183740  0.179532
# 46  33.000000  0.116914  0.114237
# 47  33.000000  0.532144  0.519958
# 48  33.000000  0.376604  0.367980
# 49  33.000000  0.429798  0.419955
# 50  33.000001  0.269751  0.263573
# 51  33.000001  0.434994  0.425032
# 52  33.000000  0.180729  0.176590
# 53  33.000000  0.086134  0.084161
# 54  33.000001  0.302536  0.295608
# 55  33.000000  0.211786  0.206936
# 56  33.000000  0.315123  0.307906
# 57  33.000000  0.467324  0.456622
# 58  33.000000  0.449449  0.439156
# 59  33.000001  0.276782  0.270443
# 60  33.000001  0.308436  0.301373
# 61  33.000000  0.445337  0.435138
# 62  33.000000  0.564532  0.551604
# 63  33.000000  0.324953  0.317512
# 64  33.000000  0.246664  0.241015
# 65  33.000000  0.368170  0.359738
# 66  33.000001  0.472752  0.461925
# 67  33.000001  0.283032  0.276550

# %%
# get labels 
lh_labels = get_annot_labels('lh.aparc.annot')    
rh_labels = get_annot_labels('rh.aparc.annot')

# %%
pmap = rois2maps(lh_dat, rh_dat, 'hedges_g', lh_labels, rh_labels)

# %%
# plot 
surface = fetch_fsaverage(density='164k')
lh, rh = surface['inflated']
dk = {'left': np.array(lh_labels), 'right': np.array(rh_labels)} # outlines 

p = Plot(lh, rh, views=['lateral', 'medial'], zoom=1.2)
p.add_layer(pmap, cmap='Blues_r', cbar_label="Hedges' g")
p.add_layer(dk, as_outline=True, cbar=False)
  
pic = p.build()

# fix legend 
cbar_ax = pic.axes[-1]
cbar_ax.set_ylabel('')
cbar_ax.set_title("Hedges' g", pad=10);
plt.title('Risperidone')
pic.savefig(os.path.join(base_path + '/figs/RIS_parcelwise_hedges_g.jpg'), dpi=300, transparent=True)
